# %% [markdown]
# # Course: ITI1120F Fall 2022
#
# # LAB 7 - Exercises

# %% [markdown]
# # Exercise 0

# %%
def sum_odd_while_v2(n):
     '''(int)->int
        Returns the sum of all odd integers between 5 and n 
     '''
     sum = 0
     i = 5
     while i <= int(n):
       sum = sum + i
       i = i + 2
    
     return sum

# %%
print(sum_odd_while_v2(10)) # expecting 21
print(sum_odd_while_v2(-7)) # expecting 0
# Out:
# 21
# 0

# %% [markdown]
# # Exercise 1

# %%
def sum_odd_for_v2(n):
  '''(int)->int
     Returns the sum of all odd integers between 5 and n 
  '''
  sum = 0
  for i in range(5, n, 2):
    sum = sum + i
  
  return sum

# %%
print(sum_odd_for_v2(10)) # expecting 21
print(sum_odd_for_v2(-7)) # expecting 0
# Out:
# 21
# 0

# %% [markdown]
# # Exercise 2

# %%
# hint: while loop will keep running until the condition is no longer turn
running = True
while running:
  input1, input2 = int(input("Insert an integer: ")), int(input("Insert an integer: "))
  print("The sum of those integers is:", input1 + input2)

  input3 = input("Do you want to continue?(if yes type 'yes') ")

  if input3 != "yes":
    running = False
# Out:
# Insert an integer: 3
# Insert an integer: 4
# The sum of those integers is: 7
# Do you want to continue?(if yes type 'yes') f

# %% [markdown]
# # <font color='Green'>** How to achieve this by For a loop in plain text : **<font>
#
# ---
# to achive the same loop using a for loop we can use the for loop like "for (some true statment):" and then if the user input something that is not yes, break that statement.

# %% [markdown]
# # Exercise 3

# %%
def first_neg(a):
  '''(list) -> int or None
  this function returns the index of the first negative number in a list.
  '''
  return_val = None
  i = 0
  while i < len(a):
    if a[i] < 0:
      return_val = i
      break
    i = i + 1
    
  return return_val

# %%
# Testcases for exercise 3
print(first_neg([2, 3, -1, 4, -2])) # expecting 2
print(first_neg([2, 3, 1, 4, 2]))   # expecting None
print(first_neg([]))                # expecting None
# Out:
# 2
# None
# None
