# %% [markdown]
# #Course: ITI1120F
# #Assignment 0
# #Garcia Affonso, Felipe
# #300290722

# %%
1+2*3
# Out:
# 7

# %%
(1+2)*3
# Out:
# 9

# %%
2**10
# Out:
# 1024

# %%
11/2
# Out:
# 5.5

# %%
1+2+3+4+5
# Out:
# 15

# %%
(25+12+40+1)/4
# Out:
# 19.5
